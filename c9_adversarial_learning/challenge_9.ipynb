# %% [markdown]
# ## Challenge 9

# %% [markdown]
# ### Importing Required Libraries

# %%
# to handle datasets
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# machine learning imports
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# attacks
from art.attacks.evasion import UniversalPerturbation
from art.estimators.classification import SklearnClassifier

# %% [markdown]
# ### Reading the data

# %%
data = pd.read_csv('android_traffic.csv')
data.head()
# Out:
#    tcp_packets  dist_port_tcp  external_ips  vulume_bytes  udp_packets  \
# 0           36              6             3          3911            0
# 1          117              0             9         23514            0
# 2          196              0             6         24151            0
# 3            6              0             1           889            0
# 4            6              0             1           882            0
#
#    tcp_urg_packet  source_app_packets  remote_app_packets  source_app_bytes  \
# 0               0                  39                  33              5100
# 1               0                 128                 107             26248
# 2               0                 205                 214            163887
# 3               0                   7                   6               819
# 4               0                   7                   6               819
#
#    remote_app_bytes  source_app_packets.1  dns_query_times    type
# 0              4140                    39                3  benign
# 1             24358                   128               11  benign
# 2             24867                   205                9  benign
# 3               975                     7                1  benign
# 4               968                     7                1  benign

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tcp_packets           7845 non-null   int64
#  1   dist_port_tcp         7845 non-null   int64
#  2   external_ips          7845 non-null   int64
#  3   vulume_bytes          7845 non-null   int64
#  4   udp_packets           7845 non-null   int64
#  5   tcp_urg_packet        7845 non-null   int64
#  6   source_app_packets    7845 non-null   int64
#  7   remote_app_packets    7845 non-null   int64
#  8   source_app_bytes      7845 non-null   int64
#  9   remote_app_bytes      7845 non-null   int64
#  10  source_app_packets.1  7845 non-null   int64
#  11  dns_query_times       7845 non-null   int64
#  12  type                  7845 non-null   object
# dtypes: int64(12), object(1)
# memory usage: 796.9+ KB

# %% [markdown]
# ### Encoding the labels

# %%
data = data.sample(frac = 1)
labels = data.type

unique_labels = ['malicious', 'benign']
encoded_labels = np.zeros((labels.shape[0], 2))
for row in range(0, labels.shape[0]):
    encoded_labels[row, unique_labels.index(labels[row])] = 1

# %% [markdown]
# ### Train - Test Split

# %%
x_train = data.iloc[:6276, :-1]
y_train = encoded_labels[:6276, :]
x_test = data.iloc[6276:, :-1]
y_test = encoded_labels[6276:, :]

# %% [markdown]
# ### Building and Training the model on original data

# %%
model = SVC(C=1)

classifier = SklearnClassifier(model=model)

classifier.fit(x_train, y_train)     # Training

# %% [markdown]
# ### Showing the model performance (on original data)

# %%
predictions = classifier.predict(x_test)
accuracy = np.sum(np.argmax(predictions, axis=0) == np.argmax(y_test, axis=0)) / len(y_test)
print("Accuracy on benign test examples: {}%".format(accuracy * 100))
# Out:
# Accuracy on benign test examples: 0.12746972594008923%

# %% [markdown]
# ### Generating the Adversarial Data using Universal Perturbation

# %%
# %%time
attack = UniversalPerturbation(classifier=classifier)

# %%
x_train_adv = attack.generate(x_train[:10],max_iter=10)
# Out:
# Universal perturbation: 0it [00:00, ?it/s]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.41s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.43s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.61s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.15s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.10s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.79s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.85s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.84s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.99s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.69s/it]
#
# Universal perturbation: 1it [02:01, 121.94s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.02s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.92s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.86s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.96s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.86s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.81s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.85s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.93s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.89s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.89s/it]
#
# Universal perturbation: 2it [04:00, 121.07s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.03s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.76s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.87s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.86s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.81s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.11s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.80s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.32s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.50s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.13s/it]
#
# Universal perturbation: 3it [06:03, 121.43s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.17s/it]
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.39s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.62s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.39s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.05s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.27s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.94s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.82s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.24s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.94s/it]
#
# Universal perturbation: 4it [08:09, 122.77s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.78s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.76s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.60s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.50s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.01s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.79s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.94s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.34s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.27s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.21s/it]
#
# Universal perturbation: 5it [10:11, 122.62s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.54s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.85s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.92s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.93s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.82s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.88s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.91s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.96s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:16<00:00, 16.46s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.08s/it]
#
# Universal perturbation: 6it [12:31, 127.96s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:16<00:00, 16.46s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.86s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.15s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.06s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.65s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.86s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.00s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.78s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.62s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.37s/it]
#
# Universal perturbation: 7it [14:57, 133.35s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.13s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.08s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.06s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.11s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:16<00:00, 16.06s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.54s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.50s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.94s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.58s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.02s/it]
#
# Universal perturbation: 8it [17:21, 136.57s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.57s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.93s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.30s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.04s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.07s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.76s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.91s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.59s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.40s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.59s/it]
#
# Universal perturbation: 9it [19:23, 131.97s/it]
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.67s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.71s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.44s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.17s/it]
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.97s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.52s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.80s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.49s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
#
# DeepFool: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.66s/it]
#
#
# DeepFool:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### New Adversarial Dataset
# As it is taking a long time to perturb the complete dataset - we will only perturb first 10 records and replace them in the original dataset.

# %%
new_x_train_adv = x_train_adv

# %% [markdown]
# ### Building and training the model on New Adversarial Dataset

# %%
model = SVC(C=1)

classifier = SklearnClassifier(model=model)

classifier.fit(x_train_adv, y_train)     # Training

# %% [markdown]
# ### Showing the new model performance (on adversarial data)

# %%
predictions = classifier.predict(x_test)
accuracy = np.sum(np.argmax(predictions, axis=0) == np.argmax(y_test, axis=0)) / len(y_test)
print("Accuracy on benign test examples: {}%".format(accuracy * 100))
